# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# Generating date range for 2024
start_date = datetime(2024, 1, 1)
end_date = datetime(2024, 12, 31)
date_range = pd.date_range(start=start_date, end=end_date)

# Generating random view counts for each day
np.random.seed(42)  # For reproducibility
view_counts = np.random.randint(1000, 5000, size=len(date_range))
likes = np.random.randint(500, 1000, size=len(date_range))
comments = np.random.randint(10, 50, size=len(date_range))

# Creating a DataFrame
data = pd.DataFrame({
    'Date': date_range,
    'ViewCount': view_counts,
    'Likes': likes,
    'Comments': comments
})

# %%
data
# Out:
#           Date  ViewCount  Likes  Comments
# 0   2024-01-01       4174    999        38
# 1   2024-01-02       4507    559        35
# 2   2024-01-03       1860    868        19
# 3   2024-01-04       2294    501        35
# 4   2024-01-05       2130    884        43
# ..         ...        ...    ...       ...
# 361 2024-12-27       2787    534        39
# 362 2024-12-28       3191    714        40
# 363 2024-12-29       3393    836        33
# 364 2024-12-30       1623    589        18
# 365 2024-12-31       2016    763        12
#
# [366 rows x 4 columns]

# %%
#change data frame to csv file and then downloading it from folder
data.to_csv('data.csv', index=False)
